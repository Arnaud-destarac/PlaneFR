# %%
import pickle
import pandas as pd

PATHS = [
    r"C:\Users\Arnaud\Documents\CIRED\PlaneFR\Code\MatMat\matmat-ademe\data\4-PlaneFR\Outputs_inter\gmrio_to_snac_s\3.10.2_pxp_2015\extensions\dom_water\F_x_dom.pkl",
]   

for path in PATHS:
    with open(path, "rb") as f:
        df = pickle.load(f)
df_tot_matmat =df.sum(axis=0).sum()
df_tot_matmat
# Out:
# np.float64(3822.8172209934637)

# %%
import pickle
import pandas as pd

PATHS = [
    r"C:\Users\Arnaud\Documents\CIRED\PlaneFR\Code\Module_PlaneFR\data\3.10.2\Base_year_2015\extensions\dom_raw_materials\d_cba_k.pkl",
]   

for path in PATHS:
    with open(path, "rb") as f:
        df = pickle.load(f)
df
# Out:
# region                France                                                  \
# Y_category        Households
# Y_sub_category   Residential
# category         Agriculture
# sub_category   Primary_Crops
# sector            Paddy rice Wheat Cereal grains nec Vegetables, fruit, nuts
# indicator
# RMC                      0.0   0.0               0.0                     0.0
#
# region                                                                        \
# Y_category
# Y_sub_category
# category
# sub_category
# sector         Oil seeds Sugar cane, sugar beet Plant-based fibers Crops nec
# indicator
# RMC                  0.0                    0.0                0.0       0.0
#
# region                            ...                                \
# Y_category                        ...                       Exports
# Y_sub_category                    ...                             E
# category                          ...     Water_and_waste_treatment
# sub_category   Farm_animals       ...                      Landfill
# sector               Cattle Pigs  ... Paper for treatment: landfill
# indicator                         ...
# RMC                     0.0  0.0  ...                      2.681519
#
# region                                                \
# Y_category
# Y_sub_category
# category
# sub_category
# sector         Plastic waste for treatment: landfill
# indicator
# RMC                                         0.691415
#
# region                                                              \
# Y_category
# Y_sub_category
# category
# sub_category
# sector         Inert/metal/hazardous waste for treatment: landfill
# indicator
# RMC                                                      6.784066
#
# region                                                 \
# Y_category
# Y_sub_category
# category
# sub_category
# sector         Textiles waste for treatment: landfill
# indicator
# RMC                                           0.45103
#
# region                                             \
# Y_category
# Y_sub_category
# category
# sub_category
# sector         Wood waste for treatment: landfill
# indicator
# RMC                                      1.049066
#
# region                                                       \
# Y_category
# Y_sub_category
# category                                       Oth_services
# sub_category                              Business_services
# sector         Membership organisation services n.e.c. (91)
# indicator
# RMC                                                5.666755
#
# region                                                            \
# Y_category
# Y_sub_category
# category
# sub_category
# sector         Recreational, cultural and sporting services (92)
# indicator
# RMC                                                   395.458418
#
# region                              \
# Y_category
# Y_sub_category
# category
# sub_category
# sector         Other services (93)
# indicator
# RMC                       5.534208
#
# region                                                        \
# Y_category
# Y_sub_category
# category
# sub_category
# sector         Private households with employed persons (95)
# indicator
# RMC                                                20.182484
#
# region
# Y_category
# Y_sub_category
# category
# sub_category
# sector         Extra-territorial organizations and bodies
# indicator
# RMC                                                   0.0
#
# [1 rows x 1000 columns]

# %%
import pickle
import pandas as pd

PATHS = [
    r"C:\Users\Arnaud\Documents\CIRED\PlaneFR\Code\MatMat\matmat-ademe\data\4-PlaneFR\Outputs\World\base-year_2019\extensions\land_use\F_x_dom.pkl",
]   

for path in PATHS:
    with open(path, "rb") as f:
        df = pickle.load(f)
df_tot_exio = df['FR'].sum().sum()
df_tot_exio
# Out:
# np.float64(456884.4815233743)

# %%
1 - df_tot_exio / df_tot_matmat
# Out:
# np.float64(-0.0242570833859288)
