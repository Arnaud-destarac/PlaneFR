# %%
import pickle
import pandas as pd

PATHS = [
    r"C:\Users\Arnaud\Documents\CIRED\PlaneFR\Code\MatMat\matmat-ademe\data\4-PlaneFR\Outputs_inter\gmrio_to_snac_s\3.10.2_pxp_2015\extensions\dom_water\F_x_dom.pkl",
]   

for path in PATHS:
    with open(path, "rb") as f:
        df = pickle.load(f)
df_tot_matmat =df.sum(axis=0).sum()
df_tot_matmat
# Out:
# np.float64(3822.8172209934637)

# %%
import pickle
import pandas as pd

PATHS = [
    r"C:\Users\Arnaud\Documents\CIRED\PlaneFR\Code\MatMat\matmat-ademe\data\4-PlaneFR\1-accounts\Exiobase\3.10.2_2019\3.10.2_pxp_2019\extensions\raw_materials\F_x_dom.pkl",
]   

for path in PATHS:
    with open(path, "rb") as f:
        df = pickle.load(f)
# exporte en csv
#df['FR'].to_excel(r"C:\Users\Arnaud\Documents\CIRED\PlaneFR\Données\Exiobase\F_x_dom_materials.xlsx")
df['FR']
# Out:
# sector                                              Paddy rice     Wheat  \
# indicator
# Primary Crops - Rice                                     82.57      0.00
# Primary Crops - Wheat                                     0.00  40604.96
# Primary Crops - Cereals n.e.c.                            0.00      0.00
# Primary Crops - Roots and tubers                          0.00      0.00
# Primary Crops - Pulses                                    0.00      0.00
# ...                                                        ...       ...
# Non-Metallic Minerals - Fertilizer minerals n.e.c.        0.00      0.00
# Non-Metallic Minerals - Chemical minerals n.e.c.          0.00      0.00
# Non-Metallic Minerals - Industrial minerals n.e.c         0.00      0.00
# Non-Metallic Minerals - Salt                              0.00      0.00
# Non-Metallic Minerals - Other non-metallic mine...        0.00      0.00
#
# sector                                              Cereal grains nec  \
# ...

# %%
PATHS = [
    r"C:\Users\Arnaud\Documents\CIRED\PlaneFR\Code\MatMat\matmat-ademe\data\4-PlaneFR\1-accounts\MatMat\3.10.2_France_2019\extensions\dom_raw_materials\F_Z.pkl",
]   

for path in PATHS:
    with open(path, "rb") as f:
        df = pickle.load(f)
# exporte en csv
#df['FR'].to_excel(r"C:\Users\Arnaud\Documents\CIRED\PlaneFR\Données\Exiobase\F_x_dom_materials.xlsx")
df
# Out:
# region                                                                                                  France  \
# category                                                                                           Agriculture
# sub_category                                                                                     Primary_Crops
# sector                                                                                              Paddy rice
# origin   region category     sub_category      sector
# domestic France Agriculture  Primary_Crops     Paddy rice                                             0.028992
#                                                Wheat                                                  0.000000
#                                                Cereal grains nec                                      0.000000
#                                                Vegetables, fruit, nuts                                0.000000
# ...

# %%
PATHS = [
    r"C:\Users\Arnaud\Documents\CIRED\PlaneFR\Code\Module_PlaneFR\data\3.10.2\2019_World\extensions\raw_materials\d_cba.pkl",
]   

for path in PATHS:
    with open(path, "rb") as f:
        df = pickle.load(f)
# exporte en csv
#df['FR'].to_excel(r"C:\Users\Arnaud\Documents\CIRED\PlaneFR\Données\Exiobase\F_x_dom_materials.xlsx")
df
# Out:
# region                                                     World
# Y_category                                                   all
# sector                                                       all
# indicator
# Primary Crops - Rice                                7.532864e+05
# Primary Crops - Wheat                               7.640759e+05
# Primary Crops - Cereals n.e.c.                      1.446088e+06
# Primary Crops - Roots and tubers                    8.535042e+05
# Primary Crops - Pulses                              8.541811e+04
# ...                                                          ...
# Non-Metallic Minerals - Chemical minerals n.e.c.    2.026269e+05
# Non-Metallic Minerals - Industrial minerals n.e.c   4.264276e+05
# Non-Metallic Minerals - Salt                        2.714749e+05
# Non-Metallic Minerals - Other non-metallic mine...  3.161830e+05
# RMC                                                 9.481321e+07
#
# [63 rows x 1 columns]

# %%
import pickle
import pandas as pd

PATHS = [
    r"C:\Users\Arnaud\Documents\CIRED\PlaneFR\Code\MatMat\matmat-ademe\data\4-PlaneFR\Outputs\World\base-year_2019\extensions\land_use\F_x_dom.pkl",
]   

for path in PATHS:
    with open(path, "rb") as f:
        df = pickle.load(f)
df_tot_exio = df['FR'].sum().sum()
df_tot_exio
# Out:
# np.float64(456884.4815233743)

# %%
1 - df_tot_exio / df_tot_matmat
# Out:
# np.float64(-0.0242570833859288)
