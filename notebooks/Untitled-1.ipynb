# %%
import pickle
import pandas as pd

PATHS = [
    r"C:\Users\Arnaud\Documents\CIRED\MatMat\260609-datapack\data\4-PlanéFR\Outputs\Monde\base-year_2019\extensions\ghg_emissions\F_Y_tot.pkl",
]   

for path in PATHS:
    with open(path, "rb") as f:
        df_1 = pickle.load(f)
mask_region = df_1.columns.get_level_values("region").isin(df)
df_1 = df_1.loc[:, mask_region]
df_1
# Out:
# Empty DataFrame
# Columns: []
# Index: [(ghg_combustion, CO2), (ghg_combustion, CH4), (ghg_combustion, N2O), (ghg_combustion, SF6), (ghg_combustion, HFC), (ghg_combustion, PFC), (ghg_other, CO2), (ghg_other, CH4), (ghg_other, N2O), (ghg_other, SF6), (ghg_other, HFC), (ghg_other, PFC)]

# %%
import pickle
import pandas as pd

PATHS = [
    r"C:\Users\Arnaud\Documents\PlaneFR\data\3.10.2\2019_Europe_27\extensions\ghg_emissions\F_Y_tot.pkl",
]   

for path in PATHS:
    with open(path, "rb") as f:
        df = pickle.load(f)
display(df.sum())
# Out:
# region  sector
# Europe  all       660.120746
# dtype: object

# %%
import pymrio

# %%
exio = pymrio.parse_exiobase3(r"C:\Users\Arnaud\Documents\CIRED\MatMat\260609-datapack\data\01-sources_public\exiobase\3.10.2\IOT_2019_pxp.zip")

# %%
exio.calc_all()

# %%
exio_39 = pymrio.parse_exiobase3(r"C:\Users\Arnaud\Documents\CIRED\MatMat\260609-datapack\data\01-sources_public\exiobase\3.9.6\IOT_2015_pxp.zip")

# %%
df = exio.air_emissions.F_Y.T.groupby(level="region").sum().T
eu_regions = df.columns.get_level_values("region").unique()[:27]
mask_region = df.columns.get_level_values("region").isin(eu_regions)
df = df.loc[:, mask_region]
df
# Out:
# region                                 AT            AU            BE  \
# stressor
# As - combustion - air           32.008235  6.429608e+01  4.917600e+01
# B(a)P - combustion - air      2310.117567  6.739933e+03  2.422304e+03
# B(b)F - combustion - air      2486.037531  7.064212e+03  2.712479e+03
# B(k)F - combustion - air      1413.985385  4.170515e+03  1.446150e+03
# CH4 - combustion - air      872796.553571  4.874691e+06  2.067286e+06
# ...                                   ...           ...           ...
# CO2 - waste - fossil - air       0.000000  0.000000e+00  0.000000e+00
# NH3 - waste - air                0.000000  0.000000e+00  0.000000e+00
# NOX - waste - air                0.000000  0.000000e+00  0.000000e+00
# PM2.5 - waste - air              0.000000  0.000000e+00  0.000000e+00
# SOx - waste - air                0.000000  0.000000e+00  0.000000e+00
#
# region                                 BG            BR            CA  \
# stressor
# As - combustion - air           28.116530  8.948263e+02  1.160577e+02
# B(a)P - combustion - air      4657.174015  1.234015e+05  1.178451e+04
# B(b)F - combustion - air      5209.197975  1.296671e+05  1.242724e+04
# B(k)F - combustion - air      2836.974331  7.629599e+04  7.258154e+03
# CH4 - combustion - air      799579.896548  6.666923e+06  1.085965e+07
# ...                                   ...           ...           ...
# CO2 - waste - fossil - air       0.000000  0.000000e+00  0.000000e+00
# NH3 - waste - air                0.000000  0.000000e+00  0.000000e+00
# NOX - waste - air                0.000000  0.000000e+00  0.000000e+00
# PM2.5 - waste - air              0.000000  0.000000e+00  0.000000e+00
# CO2 - waste - fossil - air  0.000000e+00  0.000000e+00  0.000000e+00
# NH3 - waste - air           0.000000e+00  0.000000e+00  0.000000e+00
# NOX - waste - air           0.000000e+00  0.000000e+00  0.000000e+00
# PM2.5 - waste - air         0.000000e+00  0.000000e+00  0.000000e+00
# SOx - waste - air           0.000000e+00  0.000000e+00  0.000000e+00
#
# region                                KR             LT
# stressor
# As - combustion - air       5.584043e+02      15.060374
# B(a)P - combustion - air    1.410903e+04    2002.409354
# B(b)F - combustion - air    1.645480e+04    2323.609289
# B(k)F - combustion - air    8.049824e+03    1207.663328
# CH4 - combustion - air      8.787543e+06  438226.153304
# ...                                  ...            ...
# CO2 - waste - fossil - air  0.000000e+00       0.000000
# NH3 - waste - air           0.000000e+00       0.000000
# NOX - waste - air           0.000000e+00       0.000000
# PM2.5 - waste - air         0.000000e+00       0.000000
# SOx - waste - air           0.000000e+00       0.000000
#
# [420 rows x 27 columns]

# %%
mask_region
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False])

# %%
#export en csv
F_Y_agg.to_pickle(r"C:\Users\Arnaud\Documents\CIRED\MatMat\260609-datapack\data\4-PlanéFR\Outputs\Monde\base-year_2019\extensions\air_emissions\F_Y_tot.pkl")

# %%
PATHS = [
    "data/3.10.2/base_year_2019/dom_ghg_combustion/d_cba_k.pkl",
    "data/3.10.2/base_year_2019/dom_ghg_combustion/d_cba.pkl",
]

for path in PATHS:
    with open(path, "rb") as f:
        df = pickle.load(f)

    # Sum all rows into a single row named "CO2"
    df = df.sum().rename("CO2").to_frame().T
    df.index.name = "indicator"

    with open(path, "wb") as f:
        pickle.dump(df, f)

    print(f"Done: {path}  shape={df.shape}  index={df.index.names}")



PATHS = [
    "data/3.10.2/base_year_2019/dom_raw_materials/d_cba_k.pkl",
    "data/3.10.2/base_year_2019/imp_raw_materials/d_cba_k.pkl",
    "data/3.10.2/base_year_2019/dom_raw_materials/d_cba.pkl",
    "data/3.10.2/base_year_2019/imp_raw_materials/d_cba.pkl"
]

for path in PATHS:
    with open(path, "rb") as f:
        df = pickle.load(f)

    # Sum all rows into a single row named "CO2"
    df = df.sum().rename("RMC").to_frame().T
    df.index.name = "indicator"

    with open(path, "wb") as f:
        pickle.dump(df, f)

    print(f"Done: {path}  shape={df.shape}  index={df.index.names}")
# Out:
# region                France                                                  \
# Y_category        Households
# Y_sub_category   Residential
# category         Agriculture
# sub_category   Primary_Crops
# sector            Paddy rice Wheat Cereal grains nec Vegetables, fruit, nuts
# indicator
# RMC                      0.0   0.0               0.0                     0.0
#
# region                                                                        \
# Y_category
# Y_sub_category
# category
# sub_category
# sector         Oil seeds Sugar cane, sugar beet Plant-based fibers Crops nec
# indicator
# RMC                  0.0                    0.0                0.0       0.0
#
# region                            ...                                \
# Y_category                        ...                       Exports
# Y_sub_category                    ...                             E
# category                          ...     Water_and_waste_treatment
# sub_category   Farm_animals       ...                      Landfill
# sector               Cattle Pigs  ... Paper for treatment: landfill
# indicator                         ...
# RMC                     0.0  0.0  ...                      2.959555
#
# region                                                \
# Y_category
# Y_sub_category
# category
# sub_category
# sector         Plastic waste for treatment: landfill
# indicator
# RMC                                         0.896504
#
# region                                                              \
# Y_category
# Y_sub_category
# category
# sub_category
# sector         Inert/metal/hazardous waste for treatment: landfill
# indicator
# RMC                                                      6.705771
#
# region                                                 \
# Y_category
# Y_sub_category
# category
# sub_category
# sector         Textiles waste for treatment: landfill
# indicator
# RMC                                          0.541991
#
# region                                             \
# Y_category
# Y_sub_category
# category
# sub_category
# sector         Wood waste for treatment: landfill
# indicator
# RMC                                      1.096009
#
# region                                                       \
# Y_category
# Y_sub_category
# category                                       Oth_services
# sub_category                              Business_services
# sector         Membership organisation services n.e.c. (91)
# indicator
# RMC                                               11.991706
#
# region                                                            \
# Y_category
# Y_sub_category
# category
# sub_category
# sector         Recreational, cultural and sporting services (92)
# indicator
# RMC                                                   429.226336
#
# region                              \
# Y_category
# Y_sub_category
# category
# sub_category
# sector         Other services (93)
# indicator
# RMC                      35.899755
#
# region                                                        \
# Y_category
# Y_sub_category
# category
# sub_category
# sector         Private households with employed persons (95)
# indicator
# RMC                                                17.570919
#
# region
# Y_category
# Y_sub_category
# category
# sub_category
# sector         Extra-territorial organizations and bodies
# indicator
# RMC                                                   0.0
#
# [1 rows x 1200 columns]

# %%
PATHS = [
    "C:\\Users\\Arnaud\\Documents\\CIRED\\MatMat\\260609-datapack\\data\\4-PlanéFR\\Outputs\\Europe\\base-year_2019\\extensions\\dom_biogeochemical\\d_cba.pkl",
]   

for path in PATHS:
    with open(path, "rb") as f:
        df = pickle.load(f)

df
#df_dom_ghg = df_dom_ghg.drop(columns='Exports', level='Y_category')
#df_dom_ghg.sum(axis=1).sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       5 for path in PATHS:
#       6     with open(path, "rb") as f:
# ----> 7         df = pickle.load(f)
#       9 df
#      10 #df_dom_ghg = df_dom_ghg.drop(columns='Exports', level='Y_category')
#      11 #df_dom_ghg.sum(axis=1).sum()
#
# NameError: name 'pickle' is not defined

# %%
PATHS = [
    r"C:\Users\Arnaud\Documents\CIRED\MatMat\260609-datapack\data\3-workshops\1-accounts\MatMat\3.10.2_France_2015\extensions\imp_raw_materials\d_cba_k.pkl",
]   

for path in PATHS:
    with open(path, "rb") as f:
        df_imp_ghg = pickle.load(f)

df_imp_ghg = df_imp_ghg.drop(columns='Exports', level='Y_category')
df_imp_ghg.sum(axis=1).sum()/1e3
# Out:
# np.float64(688.5152536215038)

# %%
PATHS = [
    r"C:\Users\Arnaud\Documents\CIRED\MatMat\260609-datapack\data\3-workshops\1-accounts\MatMat\3.10.2_France_2015\extensions\dom_raw_materials\d_cba_k.pkl",
]   

for path in PATHS:
    with open(path, "rb") as f:
        df_imp_ghg = pickle.load(f)

df_imp_ghg = df_imp_ghg.drop(columns='Exports', level='Y_category')
df_imp_ghg.sum(axis=1).sum()/1e3
# Out:
# np.float64(403.21255434547595)

# %%
PATHS = [
    "C:\\Users\\Arnaud\\Documents\\PlaneFR\\data\\3.10.2\\base-year_2019\\extensions\\dom_ghg_combustion\\d_cba_k.pkl",
]   

for path in PATHS:
    with open(path, "rb") as f:
        df_dom_ghg_combustion = pickle.load(f)

df_dom_ghg_combustion = df_dom_ghg_combustion.drop(columns='Exports', level='Y_category')
df_dom_ghg_combustion.sum(axis=1).sum()
# Out:
# np.float64(218.97903407409848)

# %%
import os 

PATHS = [
    "data/3.10.2/base_year_2019/dom_ghg_combustion/d_cba_k.pkl",
    "data/3.10.2/base_year_2019/dom_ghg_combustion/d_cba.pkl",
]

for path in PATHS:
    with open(path, "rb") as f:
        df = pickle.load(f)

    if "CO2" not in df.index:
        # Sum all rows into a single row named "CO2"
        df = df.sum().rename("CO2").to_frame().T
        df.index.name = "indicator"

        with open(path, "wb") as f:
            pickle.dump(df, f)

    print(f"Done: {path}  shape={df.shape}  index={df.index.names}")

    imp_path = path.replace("dom", "imp")
    os.makedirs(os.path.dirname(imp_path), exist_ok=True)
    df_zeros = df * 0
    with open(imp_path, "wb") as f:
        pickle.dump(df_zeros, f)
# Out:
# Done: data/3.10.2/base_year_2019/dom_ghg_combustion/d_cba_k.pkl  shape=(1, 1000)  index=['indicator']
# Done: data/3.10.2/base_year_2019/dom_ghg_combustion/d_cba.pkl  shape=(1, 1200)  index=['indicator']

# %%
   df_zeros
# Out:
# region                France                                                  \
# Y_category        Households
# Y_sub_category   Residential
# category         Agriculture
# sub_category   Primary_Crops
# sector            Paddy rice Wheat Cereal grains nec Vegetables, fruit, nuts
# indicator
# CO2                      0.0   0.0               0.0                     0.0
#
# region                                                                        \
# Y_category
# Y_sub_category
# category
# sub_category
# sector         Oil seeds Sugar cane, sugar beet Plant-based fibers Crops nec
# indicator
# CO2                  0.0                    0.0                0.0       0.0
#
# region                            ...                                \
# Y_category                        ...                       Exports
# Y_sub_category                    ...                             E
# category                          ...     Water_and_waste_treatment
# sub_category   Farm_animals       ...                      Landfill
# sector               Cattle Pigs  ... Paper for treatment: landfill
# indicator                         ...
# CO2                     0.0  0.0  ...                           0.0
#
# region                                                \
# Y_category
# Y_sub_category
# category
# sub_category
# sector         Plastic waste for treatment: landfill
# indicator
# CO2                                              0.0
#
# region                                                              \
# Y_category
# Y_sub_category
# category
# sub_category
# sector         Inert/metal/hazardous waste for treatment: landfill
# indicator
# CO2                                                           0.0
#
# region                                                 \
# Y_category
# Y_sub_category
# category
# sub_category
# sector         Textiles waste for treatment: landfill
# indicator
# CO2                                               0.0
#
# region                                             \
# Y_category
# Y_sub_category
# category
# sub_category
# sector         Wood waste for treatment: landfill
# indicator
# CO2                                           0.0
#
# region                                                       \
# Y_category
# Y_sub_category
# category                                       Oth_services
# sub_category                              Business_services
# sector         Membership organisation services n.e.c. (91)
# indicator
# CO2                                                     0.0
#
# region                                                            \
# Y_category
# Y_sub_category
# category
# sub_category
# sector         Recreational, cultural and sporting services (92)
# indicator
# CO2                                                          0.0
#
# region                              \
# Y_category
# Y_sub_category
# category
# sub_category
# sector         Other services (93)
# indicator
# CO2                            0.0
#
# region                                                        \
# Y_category
# Y_sub_category
# category
# sub_category
# sector         Private households with employed persons (95)
# indicator
# CO2                                                      0.0
#
# region
# Y_category
# Y_sub_category
# category
# sub_category
# sector         Extra-territorial organizations and bodies
# indicator
# CO2                                                   0.0
#
# [1 rows x 1200 columns]

# %%
PATHS = [
    "data/3.10.2/base_year_2019/dom_ghg_combustion/d_cba_k.pkl",
    "data/3.10.2/base_year_2019/dom_ghg_combustion/d_cba.pkl",
]

for path in PATHS:
    with open(path, "rb") as f:
        df = pickle.load(f)
# Sum all rows into a single row named "CO2"
df = df.sum().rename("CO2").to_frame().T
df.index.name = "indicator"
if "CO2" in df.index:
    print(df.index)
# Out:
# Index(['CO2'], dtype='str', name='indicator')

# %%
PATHS = [
    "data/3.10.2/base_year_2019/dom_ghg_emissions/unit.pkl",
]

for path in PATHS:
    with open(path, "rb") as f:
        df = pickle.load(f)

df
# Out:
# variable               unit
# source         gas
# ghg_combustion CO2  MtCO2eq
#                CH4  MtCO2eq
#                N2O  MtCO2eq
#                SF6  MtCO2eq
#                HFC  MtCO2eq
#                PFC  MtCO2eq
# ghg_other      CO2  MtCO2eq
#                CH4  MtCO2eq
#                N2O  MtCO2eq
#                SF6  MtCO2eq
#                HFC  MtCO2eq
#                PFC  MtCO2eq

# %%
# Drop first 4 column index levels
    df = df.droplevel(list(range(4)), axis=1)
    # Rename 2nd column level 'sector' -> 'indicator'
    df.columns.names = [df.columns.names[0], "indicator"]
