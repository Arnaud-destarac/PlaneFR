# %%
import pickle
import pandas as pd

PATHS = [
    r"C:\Users\Arnaud\Documents\CIRED\PlaneFR\Code\MatMat\matmat-ademe\data\4-PlaneFR\Outputs_inter\gmrio_to_snac_s\3.10.2_pxp_2015\extensions\dom_water\F_x_dom.pkl",
]   

for path in PATHS:
    with open(path, "rb") as f:
        df = pickle.load(f)
df_tot_matmat =df.sum(axis=0).sum()
df_tot_matmat
# Out:
# np.float64(3822.8172209934637)

# %%
import pickle
import pandas as pd

PATHS = [
    r"C:\Users\Arnaud\Documents\CIRED\PlaneFR\Code\Module_PlaneFR\data\3.10.2\Base_year_2015\system\x.pkl",
]   

for path in PATHS:
    with open(path, "rb") as f:
        df = pickle.load(f)
df
# Out:
# variable                                                                                                     x
# origin   region category     sub_category      sector
# domestic France Agriculture  Primary_Crops     Paddy rice                                           157.637535
#                                                Wheat                                              31577.601830
#                                                Cereal grains nec                                  40980.622688
#                                                Vegetables, fruit, nuts                            23343.339367
#                                                Oil seeds                                           6951.676353
# ...                                                                                                        ...
# import   RoW    Oth_services Business_services Membership organisation services n.e.c. (91)          97.831214
#                                                Recreational, cultural and sporting services (92)   3712.500901
#                                                Other services (93)                                  365.498154
#                                                Private households with employed persons (95)       3481.292859
#                                                Extra-territorial organizations and bodies             0.000000
#
# [400 rows x 1 columns]

# %%
import pickle
import pandas as pd

PATHS = [
    r"C:\Users\Arnaud\Documents\CIRED\PlaneFR\Code\MatMat\matmat-ademe\data\4-PlaneFR\Outputs\World\base-year_2019\extensions\land_use\F_x_dom.pkl",
]   

for path in PATHS:
    with open(path, "rb") as f:
        df = pickle.load(f)
df_tot_exio = df['FR'].sum().sum()
df_tot_exio
# Out:
# np.float64(456884.4815233743)

# %%
1 - df_tot_exio / df_tot_matmat
# Out:
# np.float64(-0.0242570833859288)
